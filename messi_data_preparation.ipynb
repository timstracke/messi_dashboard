# %%
from statsbombpy import sb

# %%
import pandas as pd

# %% [markdown]
# ## Data Preparation
# We want to build a dashboard that shows data on Lionel Messi's time in Barcelona. The data we are using is from [statsbomb](https://statsbomb.com/news/statsbomb-release-free-messi-data-all-seasons-from-2004-05-2020-21-now-available/). However, the data is very detailed and contains every pass, shot, dribble and more statistics of all Barcelona games from 2004/05 to 2020/21. Therefore, we will process this data to get stats about Messi's goals, assists, minutes played etc. Our processed dataset will be used to create a [Tableau dashboard](https://public.tableau.com/views/MessiinLaLiga/Dashboard1?:language=en-EN&publish=yes&:display_count=n&:origin=viz_share_link).

# %%
def detect_goals(df, player):
    '''
    input: df -> full game df, player (str)
    output: number of goals (int), assists_by (dict: {player: assists})
    '''

    goals = df[(df["shot_outcome"]=="Goal") & (df["player"]==player)]
    num_goals = goals.shape[0]
    
    assist_ids = goals["shot_key_pass_id"]
    assists_by = dict(df[df["id"].isin(assist_ids)]["player"].value_counts())
    
    return num_goals, assists_by

# %%
def detect_assists(df, player):
    '''
    input: df -> full game df, player (str)
    output: number of assists (int), assists_for (dict: {player: assists})
    '''  
    if not "pass_goal_assist" in df.columns:
        return 0, {}
    
    assists = df[(df["pass_goal_assist"]==True) & (df["player"]==player)]
    num_assists = assists.shape[0]

    goal_ids = assists["pass_assisted_shot_id"]
    assists_for = dict(df[df["id"].isin(goal_ids)]["player"].value_counts())
    
    
    return num_assists, assists_for

# %%
def detect_nutmegs(df, player):
    '''
    input: df -> full game df, player (str)
    output: number of nutmegs (int)
    '''
    if 'dribble_nutmeg' in df.columns:
        return df[(df["dribble_nutmeg"]==True) & (df["player"]==player)].shape[0]
    else:
        return 0

# %%
def detect_minutes_played(df, player, team):
    '''
    input: df -> full game df, player (str), team (str)
    output: minutes played (int)
    '''
    # check if player in starting XI
    player_started = False
    starting = df[(df["type"]=="Starting XI") & (df["team"]==team)]["tactics"].item()["lineup"]
    for starter in starting:
        if starter["player"]["name"] == player:
            player_started = True
            start_minute = 0
            break
            
    # check if player came from the bench
    if player_started == False:
        sub = df[df["substitution_replacement"]==player]
        if sub.shape[0] > 0:
            start_minute = df[df["substitution_replacement"]==player]["minute"].item()
        else:
            player_played = False
            return 0
    
    # check if player was replaced
    subbed_out = df[(df["substitution_replacement"].notnull()) & df["player"]==player]
    if subbed_out.shape[0] > 0:
        end_minute = subbed_out["minute"].item()
    else:
        end_minute = 90
        
    # calculate minutes played
    minutes_played = end_minute - start_minute
    return minutes_played

# %%
def collect_data(player, competition, team):
    '''
    input: player (str), competition (str), team (str)
    output: dataframe with rows for every game the team played in the competition (that is available in the database)
    '''
    df = pd.DataFrame()
    # df.columns = ["season_id", "match_id", "opponent", "num_goals", "assists_by", "num_assists", "assists_for", "num_nutmegs", "minutes_played"]
    
    # get list of available season IDs of the competition
    competitions = sb.competitions()
    seasons = competitions[competitions["competition_name"]==competition]
    competition_id = seasons["competition_id"].unique().item()
    season_ids = list(seasons["season_id"])
    
    for season_id in season_ids:
        print("Starting with season: ", season_id)
        match_ids = list(sb.matches(competition_id=competition_id, season_id=season_id)["match_id"])
        for match_id in match_ids:
            print("Starting with match: ", match_id)
            match_dict = {}
            match_df = sb.events(match_id=match_id)
            
            match_dict["season_id"] = season_id
            match_dict["match_id"] = match_id
            teams = list(match_df[:2]["team"])
            teams.remove(team)
            match_dict["opponent"] = teams[0]
            
            match_dict["num_goals"], match_dict["assists_by"] = detect_goals(match_df, player)
            match_dict["num_assists"], match_dict["assists_for"] = detect_assists(match_df, player)
            match_dict["num_nutmegs"] = detect_nutmegs(match_df, player)
            match_dict["minutes_played"] = detect_minutes_played(match_df, player, team)
            print(match_dict)
            df = df.append(match_dict, ignore_index=True)
            
    return df

# %%
df = collect_data("Lionel Andrés Messi Cuccittini", "La Liga", "Barcelona")
# Out:
# credentials were not supplied. open data access only
# Starting with season:  90
# credentials were not supplied. open data access only
# Starting with match:  3773631
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773631, 'opponent': 'Real Betis', 'num_goals': 1, 'assists_by': {'Ousmane Dembélé': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 34}
# Starting with match:  3773665
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773665, 'opponent': 'Osasuna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 2, 'assists_for': {'Moriba Kourouma Kourouma': 1, 'Jordi Alba Ramos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773497
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773497, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773660
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773660, 'opponent': 'Levante', 'num_goals': 1, 'assists_by': {'Frenkie de Jong': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773593
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773593, 'opponent': 'Villarreal', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773466
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773466, 'opponent': 'Celta Vigo', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773585
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773585, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773552
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773552, 'opponent': 'Huesca', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Frenkie de Jong': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773672
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773672, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773386
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773386, 'opponent': 'Deportivo Alavés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  3773565
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773565, 'opponent': 'Granada', 'num_goals': 2, 'assists_by': {'Antoine Griezmann': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773587
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773587, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773656
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773656, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773377
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773377, 'opponent': 'Valencia', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773457
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773457, 'opponent': 'Celta Vigo', 'num_goals': 1, 'assists_by': {'Sergio Busquets i Burgos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  3773586
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773586, 'opponent': 'Granada', 'num_goals': 1, 'assists_by': {'Antoine Griezmann': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773372
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773372, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  3773387
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773387, 'opponent': 'Levante', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773695
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773695, 'opponent': 'Valencia', 'num_goals': 2, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773369
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773369, 'opponent': 'Huesca', 'num_goals': 2, 'assists_by': {'Francisco António Machado Mota de Castro Trincão': 1, 'Sergio Busquets i Burgos': 1}, 'num_assists': 1, 'assists_for': {'Óscar Mingueza García': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773661
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773661, 'opponent': 'Getafe', 'num_goals': 2, 'assists_by': {'Sergio Busquets i Burgos': 1}, 'num_assists': 1, 'assists_for': {'Ronald Federico Araújo da Silva': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773597
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773597, 'opponent': 'Real Sociedad', 'num_goals': 2, 'assists_by': {'Sergio Busquets i Burgos': 1, 'Jordi Alba Ramos': 1}, 'num_assists': 1, 'assists_for': {'Sergino Dest': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773523
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773523, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  3773571
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773571, 'opponent': 'Real Valladolid', 'num_goals': 1, 'assists_by': {'Pedro González López': 1}, 'num_assists': 1, 'assists_for': {'Clément Lenglet': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773428
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773428, 'opponent': 'Cádiz', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3764661
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3764661, 'opponent': 'Athletic Club', 'num_goals': 2, 'assists_by': {'Pedro González López': 1, 'Antoine Griezmann': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773526
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773526, 'opponent': 'Deportivo Alavés', 'num_goals': 2, 'assists_by': {'Sergio Busquets i Burgos': 1, 'Antoine Griezmann': 1}, 'num_assists': 1, 'assists_for': {'Francisco António Machado Mota de Castro Trincão': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773474
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773474, 'opponent': 'Real Valladolid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  3773625
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773625, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Ousmane Dembélé': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  3773403
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773403, 'opponent': 'Athletic Club', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773547
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773547, 'opponent': 'Osasuna', 'num_goals': 1, 'assists_by': {'Francisco António Machado Mota de Castro Trincão': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773415
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773415, 'opponent': 'Cádiz', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3764440
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3764440, 'opponent': 'Elche', 'num_goals': 2, 'assists_by': {'Martin Braithwaite Christensen': 1, 'Frenkie de Jong': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773689
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773689, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  3773477
# credentials were not supplied. open data access only
# {'season_id': 90, 'match_id': 3773477, 'opponent': 'Real Betis', 'num_goals': 2, 'assists_by': {'Sergi Roberto Carnicer': 1}, 'num_assists': 1, 'assists_for': {'Antoine Griezmann': 1}, 'num_nutmegs': 0, 'minutes_played': 45}
# Starting with season:  42
# credentials were not supplied. open data access only
# Starting with match:  303731
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303731, 'opponent': 'Eibar', 'num_goals': 4, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1, 'Ivan Rakitić': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  303532
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303532, 'opponent': 'Leganés', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  303516
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303516, 'opponent': 'Celta Vigo', 'num_goals': 0, 'assists_by': {}, 'num_assists': 2, 'assists_for': {'Luis Alberto Suárez Díaz': 2}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303596
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303596, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303430
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303430, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Antoine Griezmann': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303725
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303725, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 2, 'assists_for': {'Luis Alberto Suárez Díaz': 1, 'Antoine Griezmann': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303504
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303504, 'opponent': 'Levante', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303451
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303451, 'opponent': 'Mallorca', 'num_goals': 3, 'assists_by': {'Luis Alberto Suárez Díaz': 1, 'Ivan Rakitić': 1, 'Antoine Griezmann': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303664
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303664, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303682
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303682, 'opponent': 'Levante', 'num_goals': 0, 'assists_by': {}, 'num_assists': 2, 'assists_for': {'Anssumane Fati': 2}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  303400
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303400, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303634
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303634, 'opponent': 'Osasuna', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303421
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303421, 'opponent': 'Deportivo Alavés', 'num_goals': 2, 'assists_by': {'Jordi Alba Ramos': 1, 'Ricard Puig Martí': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303493
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303493, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303680
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303680, 'opponent': 'Real Valladolid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Arturo Erasmo Vidal Pardo': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303479
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303479, 'opponent': 'Real Sociedad', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303615
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303615, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303696
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303696, 'opponent': 'Atlético Madrid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303487
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303487, 'opponent': 'Celta Vigo', 'num_goals': 3, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303600
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303600, 'opponent': 'Real Valladolid', 'num_goals': 2, 'assists_by': {'Ivan Rakitić': 1}, 'num_assists': 2, 'assists_for': {'Luis Alberto Suárez Díaz': 1, 'Arturo Erasmo Vidal Pardo': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  303548
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303548, 'opponent': 'Mallorca', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 2, 'assists_for': {'Martin Braithwaite Christensen': 1, 'Jordi Alba Ramos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303652
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303652, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  303674
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303674, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303470
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303470, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303700
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303700, 'opponent': 'Eibar', 'num_goals': 1, 'assists_by': {'Antoine Griezmann': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303707
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303707, 'opponent': 'Real Betis', 'num_goals': 0, 'assists_by': {}, 'num_assists': 3, 'assists_for': {'Frenkie de Jong': 1, 'Sergio Busquets i Burgos': 1, 'Clément Lenglet': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303666
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303666, 'opponent': 'Granada', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 45}
# Starting with match:  303715
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303715, 'opponent': 'Leganés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303377
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303377, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Antoine Griezmann': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303524
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303524, 'opponent': 'Atlético Madrid', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  303517
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303517, 'opponent': 'Deportivo Alavés', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  303610
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303610, 'opponent': 'Granada', 'num_goals': 1, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  303473
# credentials were not supplied. open data access only
# {'season_id': 42, 'match_id': 303473, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with season:  4
# credentials were not supplied. open data access only
# Starting with match:  15998
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15998, 'opponent': 'Leganés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Philippe Coutinho Correia': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16029
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16029, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 1, 'assists_for': {'Philippe Coutinho Correia': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16073
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16073, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Ousmane Dembélé': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  16086
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16086, 'opponent': 'Espanyol', 'num_goals': 2, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Ousmane Dembélé': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  16190
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16190, 'opponent': 'Sevilla', 'num_goals': 3, 'assists_by': {'Ousmane Dembélé': 1, 'Ivan Rakitić': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16109
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16109, 'opponent': 'Celta Vigo', 'num_goals': 1, 'assists_by': {'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16120
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16120, 'opponent': 'Getafe', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16182
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16182, 'opponent': 'Real Valladolid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16215
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16215, 'opponent': 'Real Betis', 'num_goals': 3, 'assists_by': {'Ivan Rakitić': 1, 'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16173
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16173, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  16265
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16265, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Jordi Alba Ramos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  15946
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15946, 'opponent': 'Deportivo Alavés', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16157
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16157, 'opponent': 'Valencia', 'num_goals': 2, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16136
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16136, 'opponent': 'Leganés', 'num_goals': 1, 'assists_by': {'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 27}
# Starting with match:  16248
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16248, 'opponent': 'Atlético Madrid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16056
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16056, 'opponent': 'Real Betis', 'num_goals': 2, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  16289
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16289, 'opponent': 'Levante', 'num_goals': 1, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 45}
# Starting with match:  16079
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16079, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Carles Aleña Castillo': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16149
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16149, 'opponent': 'Girona', 'num_goals': 1, 'assists_by': {'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16275
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16275, 'opponent': 'Deportivo Alavés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 30}
# Starting with match:  15973
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15973, 'opponent': 'Huesca', 'num_goals': 2, 'assists_by': {'Philippe Coutinho Correia': 1, 'Ivan Rakitić': 1}, 'num_assists': 2, 'assists_for': {'Ivan Rakitić': 1, 'Jordi Alba Ramos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16317
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16317, 'opponent': 'Eibar', 'num_goals': 2, 'assists_by': {'Ivan Rakitić': 1, 'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16131
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16131, 'opponent': 'Eibar', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  16205
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16205, 'opponent': 'Rayo Vallecano', 'num_goals': 1, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Gerard Piqué Bernabéu': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  16095
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16095, 'opponent': 'Levante', 'num_goals': 3, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1, 'Sergio Busquets i Burgos': 1}, 'num_assists': 2, 'assists_for': {'Luis Alberto Suárez Díaz': 1, 'Gerard Piqué Bernabéu': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16306
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16306, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16010
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16010, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Munir El Haddadi Mohamed': 1}, 'num_nutmegs': 1, 'minutes_played': 36}
# Starting with match:  15986
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15986, 'opponent': 'Girona', 'num_goals': 1, 'assists_by': {'Arturo Erasmo Vidal Pardo': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16240
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16240, 'opponent': 'Villarreal', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 30}
# Starting with match:  15978
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15978, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16023
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16023, 'opponent': 'Valencia', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16196
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16196, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  15956
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 15956, 'opponent': 'Real Valladolid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  16231
# credentials were not supplied. open data access only
# {'season_id': 4, 'match_id': 16231, 'opponent': 'Espanyol', 'num_goals': 2, 'assists_by': {'Malcom Filipe Silva de Oliveira': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with season:  1
# credentials were not supplied. open data access only
# Starting with match:  9855
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9855, 'opponent': 'Athletic Club', 'num_goals': 1, 'assists_by': {'Ousmane Dembélé': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9827
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9827, 'opponent': 'Las Palmas', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9799
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9799, 'opponent': 'Eibar', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9636
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9636, 'opponent': 'Las Palmas', 'num_goals': 2, 'assists_by': {'Denis Suárez Fernández': 1, 'Luis Alberto Suárez Díaz': 1}, 'num_assists': 1, 'assists_for': {'Sergio Busquets i Burgos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9609
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9609, 'opponent': 'Eibar', 'num_goals': 4, 'assists_by': {'Sergio Busquets i Burgos': 1, 'Aleix Vidal Parreu': 1, 'José Paulo Bezzera Maciel Júnior': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9575
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9575, 'opponent': 'Real Betis', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9928
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9928, 'opponent': 'Villarreal', 'num_goals': 1, 'assists_by': {'Andrés Iniesta Luján': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9736
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9736, 'opponent': 'Real Madrid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Aleix Vidal Parreu': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9742
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9742, 'opponent': 'Levante', 'num_goals': 1, 'assists_by': {'Jordi Alba Ramos': 1}, 'num_assists': 1, 'assists_for': {'José Paulo Bezzera Maciel Júnior': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9765
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9765, 'opponent': 'Real Betis', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1, 'Sergio Busquets i Burgos': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9880
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9880, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9924
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9924, 'opponent': 'Real Madrid', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9661
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9661, 'opponent': 'Athletic Club', 'num_goals': 1, 'assists_by': {'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9592
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9592, 'opponent': 'Espanyol', 'num_goals': 3, 'assists_by': {'Jordi Alba Ramos': 2, 'Ivan Rakitić': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9870
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9870, 'opponent': 'Leganés', 'num_goals': 3, 'assists_by': {'Ousmane Dembélé': 1, 'Philippe Coutinho Correia': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9783
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9783, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Gerard Piqué Bernabéu': 1}, 'num_nutmegs': 0, 'minutes_played': 33}
# Starting with match:  9700
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9700, 'opponent': 'Celta Vigo', 'num_goals': 1, 'assists_by': {'José Paulo Bezzera Maciel Júnior': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  9860
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9860, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {'Philippe Coutinho Correia': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 33}
# Starting with match:  9695
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9695, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Jordi Alba Ramos': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9794
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9794, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9717
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9717, 'opponent': 'Villarreal', 'num_goals': 1, 'assists_by': {'Sergio Busquets i Burgos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9673
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9673, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9650
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9650, 'opponent': 'Málaga', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Andrés Iniesta Luján': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9620
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9620, 'opponent': 'Girona', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9837
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9837, 'opponent': 'Atlético Madrid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9912
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9912, 'opponent': 'Deportivo La Coruna', 'num_goals': 3, 'assists_by': {'Luis Alberto Suárez Díaz': 3}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9811
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9811, 'opponent': 'Girona', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9642
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9642, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  9774
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9774, 'opponent': 'Deportivo Alavés', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9602
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9602, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'José Paulo Bezzera Maciel Júnior': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9948
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9948, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 24}
# Starting with match:  9682
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9682, 'opponent': 'Leganés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9581
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9581, 'opponent': 'Deportivo Alavés', 'num_goals': 2, 'assists_by': {'Francisco Alcácer García': 1, 'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  9726
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9726, 'opponent': 'Deportivo La Coruna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  9754
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9754, 'opponent': 'Real Sociedad', 'num_goals': 1, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  9889
# credentials were not supplied. open data access only
# {'season_id': 1, 'match_id': 9889, 'opponent': 'Celta Vigo', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 31}
# Starting with season:  2
# credentials were not supplied. open data access only
# Starting with match:  266989
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266989, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {'Neymar da Silva Santos Junior': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266357
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266357, 'opponent': 'Osasuna', 'num_goals': 2, 'assists_by': {'Sergio Busquets i Burgos': 1, 'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  267569
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267569, 'opponent': 'Real Madrid', 'num_goals': 2, 'assists_by': {'Ivan Rakitić': 1, 'Jordi Alba Ramos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267212
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267212, 'opponent': 'Leganés', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266669
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266669, 'opponent': 'Deportivo Alavés', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 31}
# Starting with match:  266892
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266892, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267220
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267220, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267670
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267670, 'opponent': 'Real Betis', 'num_goals': 2, 'assists_by': {'Sergi Roberto Carnicer': 1}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266516
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266516, 'opponent': 'Real Betis', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Luis Alberto Suárez Díaz': 1}, 'num_nutmegs': 3, 'minutes_played': 90}
# Starting with match:  267039
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267039, 'opponent': 'Las Palmas', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266477
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266477, 'opponent': 'Villarreal', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  267101
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267101, 'opponent': 'Osasuna', 'num_goals': 2, 'assists_by': {'Ivan Rakitić': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266440
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266440, 'opponent': 'Valencia', 'num_goals': 2, 'assists_by': {'Javier Alejandro Mascherano': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266033
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266033, 'opponent': 'Valencia', 'num_goals': 2, 'assists_by': {'Ivan Rakitić': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267660
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267660, 'opponent': 'Deportivo La Coruna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266273
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266273, 'opponent': 'Deportivo Alavés', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267395
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267395, 'opponent': 'Las Palmas', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266874
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266874, 'opponent': 'Athletic Club', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266731
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266731, 'opponent': 'Eibar', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266528
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266528, 'opponent': 'Espanyol', 'num_goals': 1, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  266280
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266280, 'opponent': 'Sevilla', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  267432
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267432, 'opponent': 'Eibar', 'num_goals': 2, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  267076
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267076, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267590
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267590, 'opponent': 'Málaga', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267373
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267373, 'opponent': 'Real Sociedad', 'num_goals': 2, 'assists_by': {'Luis Alberto Suárez Díaz': 1}, 'num_assists': 1, 'assists_for': {'Francisco Alcácer García': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267077
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267077, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Ivan Rakitić': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  266952
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266952, 'opponent': 'Villarreal', 'num_goals': 2, 'assists_by': {'Sergio Busquets i Burgos': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267464
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 267464, 'opponent': 'Atlético Madrid', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266299
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266299, 'opponent': 'Celta Vigo', 'num_goals': 2, 'assists_by': {'Rafael Alcântara do Nascimento': 1, 'Sergio Busquets i Burgos': 1}, 'num_assists': 2, 'assists_for': {'Samuel Yves Umtiti': 1, 'Neymar da Silva Santos Junior': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  266191
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 266191, 'opponent': 'Real Sociedad', 'num_goals': 1, 'assists_by': {'Neymar da Silva Santos Junior': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  265952
# credentials were not supplied. open data access only
# {'season_id': 2, 'match_id': 265952, 'opponent': 'Sporting Gijón', 'num_goals': 1, 'assists_by': {'Javier Alejandro Mascherano': 1}, 'num_assists': 1, 'assists_for': {'Francisco Alcácer García': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  267492
# credentials were not supplied. open data access only
# ...
# Starting with match:  69148
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69148, 'opponent': 'Sevilla', 'num_goals': 2, 'assists_by': {'Thierry Henry': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  69184
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69184, 'opponent': 'Recreativo Huelva', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 3, 'minutes_played': 90}
# Starting with match:  69173
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69173, 'opponent': 'Racing Santander', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 25}
# Starting with match:  69146
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69146, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Xavier Hernández Creus': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69182
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69182, 'opponent': 'Real Zaragoza', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68358
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 68358, 'opponent': 'Recreativo Huelva', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 26}
# Starting with match:  68361
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 68361, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Thierry Henry': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69141
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69141, 'opponent': 'Valencia', 'num_goals': 1, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Thierry Henry': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69145
# credentials were not supplied. open data access only
# {'season_id': 40, 'match_id': 69145, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 2, 'assists_for': {'Samuel Eto"o Fils': 2}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with season:  39
# credentials were not supplied. open data access only
# Starting with match:  69176
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69176, 'opponent': 'Atlético Madrid', 'num_goals': 2, 'assists_by': {'Samuel Eto"o Fils': 1, 'Giovanni van Bronckhorst': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69179
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69179, 'opponent': 'Real Zaragoza', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 2, 'minutes_played': 90}
# Starting with match:  68334
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68334, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68333
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68333, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 24}
# Starting with match:  68336
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68336, 'opponent': 'Gimnàstic Tarragona', 'num_goals': 2, 'assists_by': {'Anderson Luís de Souza': 1}, 'num_assists': 1, 'assists_for': {'Carles Puyol i Saforcada': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68326
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68326, 'opponent': 'Celta Vigo', 'num_goals': 1, 'assists_by': {'Andrés Iniesta Luján': 1}, 'num_assists': 1, 'assists_for': {'Samuel Eto"o Fils': 1}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  69162
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69162, 'opponent': 'Real Betis', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  68335
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68335, 'opponent': 'Real Madrid', 'num_goals': 3, 'assists_by': {'Samuel Eto"o Fils': 1, 'Ronaldo de Assis Moreira': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68332
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68332, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 35}
# Starting with match:  68330
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68330, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  68329
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68329, 'opponent': 'Sevilla', 'num_goals': 1, 'assists_by': {'Xavier Hernández Creus': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68341
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68341, 'opponent': 'Recreativo Huelva', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69165
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69165, 'opponent': 'Espanyol', 'num_goals': 2, 'assists_by': {'Anderson Luís de Souza': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69155
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69155, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69154
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69154, 'opponent': 'Racing Santander', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 23}
# Starting with match:  69156
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69156, 'opponent': 'Levante', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  69159
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69159, 'opponent': 'Mallorca', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69175
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69175, 'opponent': 'Deportivo La Coruna', 'num_goals': 1, 'assists_by': {'Ronaldo de Assis Moreira': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69160
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69160, 'opponent': 'Real Sociedad', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  68331
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68331, 'opponent': 'Real Zaragoza', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68328
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68328, 'opponent': 'Valencia', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68340
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68340, 'opponent': 'Racing Santander', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69174
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69174, 'opponent': 'Deportivo La Coruna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68347
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68347, 'opponent': 'Athletic Club', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 1, 'minutes_played': 90}
# Starting with match:  68327
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 68327, 'opponent': 'Osasuna', 'num_goals': 1, 'assists_by': {'Samuel Eto"o Fils': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69157
# credentials were not supplied. open data access only
# {'season_id': 39, 'match_id': 69157, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with season:  38
# credentials were not supplied. open data access only
# Starting with match:  69164
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 69164, 'opponent': 'Málaga', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 29}
# Starting with match:  68324
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68324, 'opponent': 'Deportivo Alavés', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 18}
# Starting with match:  68320
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68320, 'opponent': 'Villarreal', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68323
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68323, 'opponent': 'Celta Vigo', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  69172
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 69172, 'opponent': 'Real Betis', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 15}
# Starting with match:  68339
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68339, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 22}
# Starting with match:  68348
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68348, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68354
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68354, 'opponent': 'Racing Santander', 'num_goals': 1, 'assists_by': {'Samuel Eto"o Fils': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68351
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68351, 'opponent': 'Real Zaragoza', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68317
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68317, 'opponent': 'Real Zaragoza', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 24}
# Starting with match:  68350
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68350, 'opponent': 'Atlético Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68325
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68325, 'opponent': 'Mallorca', 'num_goals': 2, 'assists_by': {'Sylvio Mendes Campos Junior': 1, 'Ronaldo de Assis Moreira': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 17}
# Starting with match:  68321
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68321, 'opponent': 'Sevilla', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68319
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68319, 'opponent': 'Real Madrid', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68342
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68342, 'opponent': 'Athletic Club', 'num_goals': 1, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68322
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68322, 'opponent': 'Cádiz', 'num_goals': 0, 'assists_by': {}, 'num_assists': 1, 'assists_for': {'Samuel Eto"o Fils': 1}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with match:  68318
# credentials were not supplied. open data access only
# {'season_id': 38, 'match_id': 68318, 'opponent': 'Osasuna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 90}
# Starting with season:  37
# credentials were not supplied. open data access only
# Starting with match:  68314
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68314, 'opponent': 'Málaga', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 9}
# Starting with match:  68313
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68313, 'opponent': 'Osasuna', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 18}
# Starting with match:  68316
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68316, 'opponent': 'Albacete', 'num_goals': 1, 'assists_by': {'Ronaldo de Assis Moreira': 1}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 3}
# Starting with match:  68315
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68315, 'opponent': 'Levante', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 33}
# Starting with match:  69153
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 69153, 'opponent': 'Albacete', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': -6}
# Starting with match:  68352
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68352, 'opponent': 'Getafe', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 5}
# Starting with match:  68353
# credentials were not supplied. open data access only
# {'season_id': 37, 'match_id': 68353, 'opponent': 'Espanyol', 'num_goals': 0, 'assists_by': {}, 'num_assists': 0, 'assists_for': {}, 'num_nutmegs': 0, 'minutes_played': 9}

# %%
df.head()
# Out:
#                assists_by                                        assists_for  \
# 0  {'Ousmane Dembélé': 1}                                                 {}
# 1                      {}  {'Moriba Kourouma Kourouma': 1, 'Jordi Alba Ra...
# 2                      {}                                                 {}
# 3  {'Frenkie de Jong': 1}                                                 {}
# 4                      {}                                                 {}
#
#     match_id  minutes_played  num_assists  num_goals  num_nutmegs  \
# 0  3773631.0            34.0          0.0        1.0          0.0
# 1  3773665.0            90.0          2.0        0.0          0.0
# 2  3773497.0            90.0          0.0        0.0          0.0
# 3  3773660.0            90.0          0.0        1.0          0.0
# 4  3773593.0            90.0          0.0        1.0          0.0
#
#       opponent  season_id
# 0   Real Betis       90.0
# 1      Osasuna       90.0
# 2  Real Madrid       90.0
# 3      Levante       90.0
# 4   Villarreal       90.0

# %%
assists_by_df = pd.DataFrame()
assists_for_df = pd.DataFrame()
for i, row in df.iterrows():
    d = {}
    d["season_id"] = row["season_id"]
    d["match_id"] = row["match_id"]
    d["opponent"] = row["opponent"]
    
    # get assists by
    for player, num_assists in row["assists_by"].items():
        assists_by_dict = d.copy()
        assists_by_dict["player"] = player
        assists_by_dict["num_assists"] = num_assists
        assists_by_df = assists_by_df.append(assists_by_dict, ignore_index=True)
        
    
    # get assists for
    for player, num_assists in row["assists_for"].items():
        assists_for_dict = d.copy()
        assists_for_dict["player"] = player
        assists_for_dict["num_assists"] = num_assists
        assists_for_df = assists_for_df.append(assists_for_dict, ignore_index=True)

# %%
df.to_csv("messi_barcelona_games.csv", index=False)
assists_for_df.to_csv("messi_assists.csv", index=False)
assists_by_df.to_csv("messi_assisted.csv", index=False)

# %% [markdown]
# [Tableau dashboard](https://public.tableau.com/views/MessiinLaLiga/Dashboard1?:language=en-EN&publish=yes&:display_count=n&:origin=viz_share_link)
